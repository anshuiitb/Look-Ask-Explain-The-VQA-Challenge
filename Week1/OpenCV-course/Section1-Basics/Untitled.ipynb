# %% [markdown]
# <h2>
#     Installations
# </h2>

# %%
! python --version
# Out:
# Python 3.10.19

# %%
import cv2
cv2.__version__
# Out:
# '4.12.0'

# %%
# !pip install caer
# Out:
# ...
#   Using cached caer-2.1.1-py3-none-any.whl.metadata (8.7 kB)
# ...
#   Using cached opencv_contrib_python-4.12.0.88-cp37-abi3-win_amd64.whl.metadata (20 kB)
# ...
#   Using cached mypy-1.19.0-cp310-cp310-win_amd64.whl.metadata (2.2 kB)
# ...
#   Using cached mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# ...
#   Using cached pathspec-0.12.1-py3-none-any.whl.metadata (21 kB)
# ...
#   Using cached librt-0.7.3-cp310-cp310-win_amd64.whl.metadata (1.4 kB)
# Using cached caer-2.1.1-py3-none-any.whl (320 kB)
# Using cached mypy-1.19.0-cp310-cp310-win_amd64.whl (10.0 MB)
# Using cached librt-0.7.3-cp310-cp310-win_amd64.whl (54 kB)
# Using cached mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Using cached pathspec-0.12.1-py3-none-any.whl (31 kB)
# ...
#    ---------------------------------------- 0.0/45.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/45.3 MB ? eta -:--:--
#    ---------------------------------------- 0.5/45.3 MB 2.8 MB/s eta 0:00:17
# ...

# %% [markdown]
# <h2>
#     Reading Images & video
# </h2>

# %%
import cv2 as cv

# %%
img = cv.imread('/Week1/OpenCV-course/Resources/Photos/cat.jpg')

# %%
# cv.imshow('cat_pic' , img)
# cv.waitkey(0)

# not responding : taking too much time if using jupyter notebook
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 2
#       1 cv.imshow('cat_pic' , img)
# ----> 2 cv.waitkey(0)
#       4 # not responding : taking too much time
#
# AttributeError: module 'cv2' has no attribute 'waitkey'
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import matplotlib.pyplot as plt
img_rgb = cv.cvtColor(img, cv.COLOR_BGR2RGB)

plt.figure(figsize=(8,6))
plt.imshow(img_rgb)
plt.axis('off')
plt.show()

# %%
# while True:
#     cv.imshow("cat_pic", img)
#     if cv.waitKey(100) & 0xFF == 27:  # press Esc to quit
#         break
# cv2.destroyAllWindows()

# %%
img2 = cv.imread('/Week1/OpenCV-course/Resources/Photos/cat_large.jpg')

# %%
import matplotlib.pyplot as plt
img_rgb2 = cv.cvtColor(img2, cv.COLOR_BGR2RGB)

plt.figure(figsize=(8,6))
plt.imshow(img_rgb2)
plt.axis('off')
plt.show()

# %%
capture = cv.VideoCapture(r"/Week1/OpenCV-course\Resources\Videos\dog.mp4")

# %%
# capture = cv.VideoCapture(1) # local webcams on our computer
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 capture = cv.VideoCapture(1) # local webcams on our computer
#
# NameError: name 'cv' is not defined

# %%
from IPython.display import display, clear_output
from PIL import Image
import numpy as np

path = r"/Week1/OpenCV-course\Resources\Videos\dog.mp4"
cap = cv.VideoCapture(path)
if not cap.isOpened():
    raise SystemExit(f"Cannot open video: {path}")

try:
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        # BGR -> RGB
        frame = cv.cvtColor(frame, cv.COLOR_BGR2RGB)
        # optionally resize for speed
        h, w = frame.shape[:2]
        if max(h, w) > 720:
            scale = 720 / max(h, w)
            frame = cv.resize(frame, (int(w*scale), int(h*scale)), interpolation=cv.INTER_AREA)

        img = Image.fromarray(frame)
        clear_output(wait=True)
        display(img)
        # delay for approx frame rate (in ms)
        if cv.waitKey(30) & 0xFF == ord('q'):
            break
finally:
    cap.release()
    clear_output(wait=True)
# Out:
# <PIL.Image.Image image mode=RGB size=720x405>
